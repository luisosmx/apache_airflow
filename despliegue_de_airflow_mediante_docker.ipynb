# %% [markdown]
# <a href="https://colab.research.google.com/github/luisosmx/apache_airflow/blob/main/despliegue_de_airflow_mediante_docker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Pasos para desplegar airflow mediante docker desktop en windows
#
# 1.- Primero se debe descargar docker desktop en la maquina https://www.docker.com/products/docker-desktop/
#
# 2.- Se crea una carpeta con el nombre de "airflow" desde la carpeta raiz de la PC
# ![Screenshot_2.png](data:image/png;base64,...)
#
# 3.- Abrimos esta carpeta para añadir tres carpetas mas que tengan el nombre de  "dags", "logs", y "plugins"
#
# ![Screenshot_3.png](data:image/png;base64,...)
#
# 4.- Mediante VSC (visual studio code) agrgamos la carpeta que creamos solo arrastrando desde nuestros archivos a la pantalla de VSC y creamos un archivo con el nombre de
